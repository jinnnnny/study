# %% [markdown]
# # 04과 [예제] 숫자형변수_시각화

# %% [markdown]
# * [4-1] 히스토그램

# %%
# 0) 라이브러리 로딩

import matplotlib.pyplot as plt

# ----------------------------------------------
# 1) 히스토그램 기본

# age = [19,20,23,46,21,25,26,25,28,31,37,24,28,34,38,33,32,29,27,24]
# plt.hist(age, bins = 5, edgecolor = 'gray')
# plt.xlabel('Age')
# plt.ylabel('Frequency')
# # plt.savefig('a') #에이블 강의장에서는 a.png
# plt.show()

# ----------------------------------------------
# 2) 구간의 갯수를 조정해 봅시다.

# age = [19,20,23,46,21,25,26,25,28,31,37,24,28,34,38,33,32,29,27,24]
# plt.hist(age, bins = 10, edgecolor = 'gray')
# plt.xlabel('Age')
# plt.ylabel('Frequency')
# # plt.savefig('a')
# plt.show()

# ----------------------------------------------
# 3) 구간 값과 갯수를 확인해 봅시다.

# age = [19,20,23,46,21,25,26,25,28,31,37,24,28,34,38,33,32,29,27,24]
# hist1 = plt.hist(age, bins = 5, edgecolor = 'gray')

# print(hist1)
# print(type(hist1))
# print('-' * 50)
# print('빈도수 : ', hist1[0])
# print('구간값 : ', hist1[1])

# ----------------------------------------------
# 4) 연습문제를 풀어 봅시다.
import pandas as pd
data = pd.read_csv("https://bit.ly/3HaMAtZ", usecols = ['Age','Fare']) #usecols : 가져올 칼럼 지정

#Age에 칼럼에 대해 히스토그램을 그려 봅시다.
bins = 8, 16, 32, 64
plt.hist(data['Age'], bins = 8, edgecolor = 'gray')
plt.xlabel('Age')
plt.ylabel('Fare')
# plt.savefig('a') #에이블 강의장에서는 a.png
plt.show()


#Age에 칼럼에 대해 히스토그램을 그릴때, 
#빈도수와 구간값을 살펴 봅시다.
result[0] #빈도수
result[1] #구간값
bins = 8

hist1 = plt.hist(data['Age'], bins = 8, edgecolor = 'gray')

print(hist1)
print(type(hist1))
print('-' * 50)
print('빈도수 : ', hist1[0])
print('구간값 : ', hist1[1])
# Out:
# (array([ 68., 115., 266., 291.,  87.,  42.,  17.,   5.]), array([ 0.42  , 10.3675, 20.315 , 30.2625, 40.21  , 50.1575, 60.105 ,
#        70.0525, 80.    ]), <BarContainer object of 8 artists>)
# <class 'tuple'>
# --------------------------------------------------
# 빈도수 :  [ 68. 115. 266. 291.  87.  42.  17.   5.]
# 구간값 :  [ 0.42   10.3675 20.315  30.2625 40.21   50.1575 60.105  70.0525 80.    ]

# %% [markdown]
# * [4-2] 밀도함수 그래프

# %%
# 0) 라이브러리 로딩

import matplotlib.pyplot as plt
import pandas as pd

# # ----------------------------------------------
# # 1) 밀도함수 그래프.

# age = [19,20,23,46,21,25,26,25,28,31,37,24,28,34,38,33,32,29,27,24]
# age = pd.Series(age)
# age.plot(kind = 'kde')
# # plt.savefig('a')

# ----------------------------------------------
# # 2) 연습문제

# age = [19,20,23,46,21,25,26,25,28,31,37,24,28,34,38,33,32,29,27,24]

# 히스토그램을 그리시오.
plt.hist(age, bins = 10, edgecolor = 'grey')
plt.show()


# 밀도함수 그래프를 그리시오.

age = pd.Series(age)
age.plot(kind = 'kde')
plt.show()
# 두 그래프는 어떤 차이가 있나요?

# %%
#추가
data.head()

#기초통계량
# data['Fare'].decribe

#histogram
plt.hist(data['Fare'],bins = 50, edgecolor='grey')
plt.show()

#density plot
data['Fare'].plot(kind = 'kde')
plt.show()

# %% [markdown]
# * [4-3] boxplot

# %%
# 0) 라이브러리 로딩

import matplotlib.pyplot as plt

# ----------------------------------------------

# 1) boxplot 기본

# age = [19,20,23,46,21,25,26,25,28,31,37,24,28,34,38,33,32,29,27,24]
# plt.boxplot(age)
# # plt.savefig('a.png')
# plt.show()

# # ----------------------------------------------
# # 2) 옆으로 그리기

# age = [19,20,23,46,21,25,26,25,28,31,37,24,28,34,38,33,32,29,27,24]
# plt.boxplot(age, vert = False)
# # plt.savefig('a.png')
# plt.show()

# # ----------------------------------------------
# # 3) 박스플로의 값들 가져오기

# age = [19,20,23,46,21,25,26,25,28,31,37,24,28,34,38,33,32,29,27,24]
# box1 = plt.boxplot(age)

# print(type(box1))
# print(box1.keys())
# print('-'* 50)
# print(box1['whiskers'])
# print(box1['whiskers'][0].get_ydata()) # 아래쪽 수염의 max, min
# print(box1['whiskers'][1].get_ydata()) # 위쪽 수염의 min, max

# ----------------------------------------------
# 4) 연습문제를 풀어 봅시다.
import pandas as pd
data = pd.read_csv("https://bit.ly/3HaMAtZ", usecols = ['Age','Fare'])
# Age에 칼럼에 대해 

# 박스 플롯을 그려 봅시다.
plt.boxplot(data['Age'])
plt.show()

# 박스 플롯을 옆으로 그려 봅시다.
plt.boxplot(data['Age'], vert = False)
plt.show()
            

# 박스 플롯의 아래 수염의 min, max, 윗 수염의 min, max
box1 = plt.boxplot(data['Age'])

print(type(box1))
print(box1.keys())
print('-'* 50)
print(box1['whiskers'])
print(box1['whiskers'][0].get_ydata()) # 아래쪽 수염의 max, min
print(box1['whiskers'][1].get_ydata()) # 위쪽 수염의 min, max
# Out:
# <class 'dict'>
# dict_keys(['whiskers', 'caps', 'boxes', 'medians', 'fliers', 'means'])
# --------------------------------------------------
# [<matplotlib.lines.Line2D object at 0x00000208A6F2C700>, <matplotlib.lines.Line2D object at 0x00000208A6F2CA60>]
# [21.77  0.67]
# [35.9 57. ]

# %% [markdown]
# * [4-4] 바이올린 플롯

# %%
# 0) 라이브러리 로딩

import matplotlib.pyplot as plt
import numpy as np

# ----------------------------------------------
# 1) 바이올린 플롯 그리기

# age = [19,20,23,46,21,25,26,25,28,31,37,24,28,34,38,33,32,29,27,24]
# age_m = np.mean(age)

# plt.violinplot(age, vert = False, showmeans=True)
# plt.text( age_m - 1, 0.85 , age_m)
# plt.savefig('a.png')

# --------------------------------------------------
# 2) 4가지 플롯을 한꺼번에 그려 봅시다.

# age = [19,20,23,46,21,25,26,25,28,31,37,24,28,34,38,33,32,29,27,24]

# plt.subplot(2,2,1)
# plt.hist(age, bins = 8, edgecolor = 'grey')

# plt.subplot(2,2,2)
# plt.boxplot(age, vert = False)

# plt.subplot(2,2,3)
# pd.Series(age).plot(kind = 'kde')

# plt.subplot(2,2,4)
# plt.violinplot(age, vert = False, showmeans=True)

# plt.savefig('a.png')

# --------------------------------------------------
# 3) 연습문제를 풀어 봅시다.

import pandas as pd
data = pd.read_csv("https://bit.ly/3HaMAtZ", usecols = ['Age','Fare'])
# Age에 칼럼에 대해 

# 바이올린 플롯을 그려봅시다.
# 평균 값도 포함시켜 봅시다.



# 4가지 플롯을 한꺼번에 그려 봅시다.
plt.subplot(2,2,1)
plt.hist(data['Age'],bins=8, edgecolor='grey')

plt.subplot(2,2,2)
plt.boxplot(data['Age'],vert = False)

plt.subplot(2,2,3)
pd.Series(data['Age']).plot(kind='kde')

plt.subplot(2,2,4)
plt.violinplot(data['Age'],vert = False, showmeans = True)

plt.show()

# --------------------------------------------------
# 4) 시계열 데이터 시각화
# import pandas as pd

# air = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/air2.csv ')
# air['Date'] = pd.to_datetime(air['Date']) # 날짜 형식으로 변환

# plt.plot('Date', 'Ozone', 'g-', data = air, label = 'Ozone')
# plt.plot('Date', 'Temp', 'r-', data = air, label = 'Temp')

# plt.xlabel('Date')
# plt.legend()
# plt.savefig('a.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

air = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/air2.csv ')
air['Date'] = pd.to_datetime(air['Date']) # 날짜 형식으로 변환

plt.plot('Date', 'Ozone', 'g-', data = air, label = 'Ozone')
plt.plot('Date', 'Temp', 'r-', data = air, label = 'Temp')

plt.xlabel('Date')
plt.legend()
plt.savefig('a.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

titanic = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/titanic.1.csv')

plt.subplot(2,2,1)
plt.hist(titanic['Age'], bins = 16, edgecolor = 'grey')

plt.subplot(2,2,2)
plt.boxplot(titanic['Age'], vert = False)

plt.subplot(2,2,3)
titanic['Age'].plot(kind = 'kde')

plt.subplot(2,2,4)
plt.violinplot(titanic['Age'], vert = False, showmeans=True)

plt.savefig('a.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

titanic = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/titanic.1.csv')

plt.figure(figsize = (8,6))
plt.subplot(2,1,1)
plt.hist(titanic['Age'], bins = 16, edgecolor = 'grey')

plt.subplot(2,1,2)
plt.boxplot(titanic['Age'], vert = False)
plt.savefig('a.png')
